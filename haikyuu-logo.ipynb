# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sin = 0
for i in range(1, 10):
    sin += np.sin(i*np.linspace(0, 2*np.pi, 3000))
# dft = np.fft.fft(sin)
# i_dft = np.fft.ifft(dft)
fig, ax = plt.subplots(figsize=(8, 6), dpi=300)
ax.plot(sin)
